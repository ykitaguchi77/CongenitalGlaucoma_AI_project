# %% [markdown]
# <a href="https://colab.research.google.com/github/ykitaguchi77/CongenitalGlaucoma_AI_project/blob/main/Pickup_under10_fromNewImageList.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import glob

path = glob.glob(r"C:\Users\ykita\OneDrive\デスクトップ\眼位写真NEW/*")

# %%
#画像番号-日付-年齢-......jpgとなっている
os.path.basename(path[0])
# Out:
# '1-20141126-38-091804_eb568e2ac952f8be45ec0ac9ae800120b7c988b60ac499ca87306986d218f554.jpg'

# %%
#年齢を抜き出し
os.path.basename(path[0]).split("-")[2]
# Out:
# '38'

# %%
#10歳以下のリスト
u10_path_list = [x for x in path if int(os.path.basename(x).split("-")[2])<10]
u10_path_list

# %%
u10_num_list = [int(os.path.basename(x).split("-")[0]) for x in u10_path_list]
u10_num_list = list(set(u10_num_list))
u10_num_list.sort()
u10_num_list
# Out:
# [6,
#  9,
#  12,
#  18,
#  21,
#  22,
#  25,
#  29,
#  33,
#  37,
#  41,
#  43,
#  47,
#  48,
#  49,
#  51,
#  52,
#  53,
#  54,
#  60,
#  68,
#  72,
#  74,
#  79,
#  83,
#  84,
#  93,
#  94,
#  95,
#  97,
#  100,
#  102,
#  104,
#  105,
#  116,
#  117,
#  123,
#  125,
#  133,
#  135,
#  136,
#  141,
#  142,
#  143,
#  145,
#  151,
#  152,
#  154,
#  160,
#  162,
#  166,
#  169,
#  173,
#  175,
#  181,
#  182,
#  187,
#  197,
#  201,
#  203,
#  205,
#  213,
#  218,
#  220,
#  224,
#  226,
#  228,
#  238,
#  241,
#  254,
#  257,
#  263,
#  265,
#  268,
#  272,
#  277,
#  283,
#  291,
#  293,
#  301,
#  302,
#  304,
#  305,
#  306,
#  307,
#  312,
#  313,
#  316,
#  318,
#  327,
#  331,
#  334,
#  353,
#  358,
#  359,
#  361,
#  363,
#  365,
#  367,
#  371,
#  386,
#  389,
#  392,
#  396,
#  400,
#  403,
#  405,
#  408,
#  414,
#  415,
#  417,
#  418,
#  420,
#  422,
#  424,
#  427,
#  431,
#  434,
#  435,
#  436,
#  441,
#  443,
#  445,
#  449,
#  450,
#  453,
#  457,
#  462,
#  463,
# ...
